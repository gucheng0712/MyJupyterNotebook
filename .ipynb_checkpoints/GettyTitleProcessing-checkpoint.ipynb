# %%
import pandas as pd
from pandas import ExcelFile
df = pd.read_excel('getty_dataset/TECH 2709 Getty Dataset.xlsx')

# %%
print(df.head())
# Out:
#                                           Unnamed: 0  object ID  \
# 0                                    collection URL:        NaN
# 1  http://www.getty.edu/art/collection/search/?pg...        NaN
# 2                                                NaN        NaN
# 3                                                NaN        NaN
# 4                                    Nikita (page 1)      570.0
#
#                                                Title  \
# 0  (note ?pg= variable sets the page you can jump...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4         Portrait of Anne, Countess of Chesterfield
#
#                                  Artist/Maker       Date  \
# 0                                         NaN        NaN
# 1                                         NaN        NaN
# 2                                         NaN        NaN
# 3                                         NaN        NaN
# 4  Thomas Gainsborough (English, 1727 - 1788)  1777–1778
#
#                                          Description  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4  Anne Thistlewaite, the Countess of Chesterfiel...
#
#                                     Primary Sentence # of People  Gender  Age  \
# 0                                                NaN         NaN     NaN  NaN
# 1                                                NaN         NaN     NaN  NaN
# 2                                                NaN         NaN     NaN  NaN
# 3                                                NaN         NaN     NaN  NaN
# 4  Anne Thistlewaite, the Countess of Chesterfiel...           1  female  20s
#
#    Emotion                                              Image  Unnamed: 12  \
# 0      NaN                                                NaN          NaN
# 1      NaN                                                NaN          NaN
# 2      NaN                                                NaN          NaN
# 3      NaN                                                NaN          NaN
# 4  sadness  570-thomas-gainsborough-portrait-of-anne-count...          NaN
#
#    Unnamed: 13  Unnamed: 14  Unnamed: 15  Unnamed: 16  Unnamed: 17
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
# 3          NaN          NaN          NaN          NaN          NaN
# 4          NaN          NaN          NaN          NaN          NaN

# %%
df.drop(df.index[0:4],axis=0)
# Out:
#                             object ID  \
# Nikita (page 1)                 570.0
# Zane Zukovsky(pages 2-8)       1135.0
# Kane A. Boyer (pages 9-15)      815.0
# Tom Gu (pages 16-22)         105081.0
# Sungmin Lee (pages 23-29)    220297.0
# (25~Infinite)                   697.0
# Joab (pages 30-36)              568.0
# Camille (pages 37-43)           737.0
# Edi (pages 44-50)            103264.0
# Matthew (pages 51-57)           934.0
# Ben (pages 58-64)               775.0
# Kyro (pages 65-71)           326685.0
#
#                                                                         Title  \
# Nikita (page 1)                    Portrait of Anne, Countess of Chesterfield
# Zane Zukovsky(pages 2-8)    Allegory of Charles IX as Mars and Allegory of...
# Kane A. Boyer (pages 9-15)        Portrait of Francisco de los Cobos y Molina
# Tom Gu (pages 16-22)        The Miraculous Communion of Saint Catherine of...
# Sungmin Lee (pages 23-29)                                 Head of a Young Man
# (25~Infinite)                                          An Allegory of Passion
# Joab (pages 30-36)                         Arrival of Saint Ursula at Cologne
# Camille (pages 37-43)                         Aurora Taking Leave of Tithonus
# Edi (pages 44-50)           John, Fourteenth Lord Willoughby de Broke, and...
# Matthew (pages 51-57)                                          Bust of Winter
# Ben (pages 58-64)                               Rinaldo and the Mirror-Shield
# Kyro (pages 65-71)          Detached leaf from the Gradual of the Carthusi...
#
#                                                                Artist/Maker  \
# Nikita (page 1)                  Thomas Gainsborough (English, 1727 - 1788)
# Zane Zukovsky(pages 2-8)                                    Léonard Limosin
# Kane A. Boyer (pages 9-15)  Jan Gossaert (Netherlandish, about 1478 - 1532)
# Tom Gu (pages 16-22)                                     Domenico Beccafumi
# Sungmin Lee (pages 23-29)                                           Unknown
# (25~Infinite)                                      Hans Holbein the Younger
# Joab (pages 30-36)                                           Bernardo Daddi
# Camille (pages 37-43)             Francesco Solimena (Italian, 1657 - 1747)
# Edi (pages 44-50)                                            Johann Zoffany
# Matthew (pages 51-57)                                         Paul Heermann
# Ben (pages 58-64)                                          Francesco Maffei
# Kyro (pages 65-71)                            Niccolò di Giacomo da Bologna
#
#                                        Date  \
# Nikita (page 1)                   1777–1778
# Zane Zukovsky(pages 2-8)               1573
# Kane A. Boyer (pages 9-15)  about 1530–1532
# Tom Gu (pages 16-22)              1513–1515
# Sungmin Lee (pages 23-29)         1320–1330
# (25~Infinite)                     1532–1536
# Joab (pages 30-36)                     1333
# Camille (pages 37-43)                  1704
# Edi (pages 44-50)                      1766
# Matthew (pages 51-57)                  1700
# Ben (pages 58-64)                 1650–1655
# Kyro (pages 65-71)                1392–1402
#
#                                                                   Description  \
# Nikita (page 1)             Anne Thistlewaite, the Countess of Chesterfiel...
# Zane Zukovsky(pages 2-8)    These small enamel plaques present allegorical...
# Kane A. Boyer (pages 9-15)  Francesco de los Cobos y Molina, the powerful ...
# Tom Gu (pages 16-22)                                                      NaN
# Sungmin Lee (pages 23-29)   The delicately painted head of a youth on a si...
# (25~Infinite)               The painted roundel in the center of this diam...
# Joab (pages 30-36)          Three boats approach the German city of Cologn...
# Camille (pages 37-43)       In Greek legend, Eos, or Aurora, the goddess o...
# Edi (pages 44-50)           John Peyto-Verney, fourteenth Lord Willoughby ...
# Matthew (pages 51-57)       Shrouded in a heavy hooded cloak, an elderly m...
# Ben (pages 58-64)           In Torquato Tasso's 1581 epic poem Gerusalemme...
# Kyro (pages 65-71)                                             No Description
#
#                                                              Primary Sentence  \
# Nikita (page 1)             Anne Thistlewaite, the Countess of Chesterfiel...
# Zane Zukovsky(pages 2-8)    These small enamel plaques present allegorical...
# Kane A. Boyer (pages 9-15)  Francesco de los Cobos y Molina, the powerful ...
# Tom Gu (pages 16-22)                                                      NaN
# Sungmin Lee (pages 23-29)   The delicately painted head of a youth on a si...
# (25~Infinite)               The painted roundel in the center of this diam...
# Joab (pages 30-36)          Three boats approach the German city of Cologn...
# Camille (pages 37-43)       Solimena illustrates a moment later in the nar...
# Edi (pages 44-50)           John Peyto-Verney, fourteenth Lord Willoughby ...
# Matthew (pages 51-57)       As a personification of winter, the bust gives...
# Ben (pages 58-64)           In Torquato Tasso's 1581 epic poem Gerusalemme...
# Kyro (pages 65-71)                                        No Primary Sentence
#
#                            # of People  Gender  Age   Emotion  \
# Nikita (page 1)                      1  female  20s   sadness
# Zane Zukovsky(pages 2-8)             1    male  20s       joy
# Kane A. Boyer (pages 9-15)           1    male  40s   neutral
# Tom Gu (pages 16-22)                 5    male  30s      fear
# Sungmin Lee (pages 23-29)            1    male  20s   neutral
# (25~Infinite)                        1    male  30s   neutral
# Joab (pages 30-36)                   5    male  40s       joy
# Camille (pages 37-43)               5+  female  30s   neutral
# Edi (pages 44-50)                  NaN     NaN  NaN       NaN
# Matthew (pages 51-57)                1    male  50s     anger
# Ben (pages 58-64)                    3    male  20s       NaN
# Kyro (pages 65-71)                   3    male  30s  contempt
#
#                                                                         Image  \
# Nikita (page 1)             570-thomas-gainsborough-portrait-of-anne-count...
# Zane Zukovsky(pages 2-8)    1135-leonard-limosin-allegory-of-charles-ix-as...
# Kane A. Boyer (pages 9-15)  815-jan-gossaert-portrait-of-francisco-de-los-...
# Tom Gu (pages 16-22)        105081-domenico-beccafumi-the-miraculous-commu...
# Sungmin Lee (pages 23-29)   220297-unknown-maker-french-or-belgian-head-of...
# (25~Infinite)               697-hans-holbein-the-younger-an-allegory-of-pa...
# Joab (pages 30-36)          568-bernardo-daddi-arrival-of-saint-ursula-at-...
# Camille (pages 37-43)       737-francesco-solimena-aurora-taking-leave-of-...
# Edi (pages 44-50)           103264-johann-zoffany-john-fourteenth-lord-wil...
# Matthew (pages 51-57)       934-paul-heermann-bust-of-winter-german-about-...
# Ben (pages 58-64)           775-francesco-maffei-rinaldo-and-the-mirror-sh...
# Kyro (pages 65-71)          326685-niccolo-di-giacomo-da-bologna-detached-...
#
#                             Unnamed: 11  Unnamed: 12  Unnamed: 13  \
# Nikita (page 1)                     NaN          NaN          NaN
# Zane Zukovsky(pages 2-8)            NaN          NaN          NaN
# Kane A. Boyer (pages 9-15)          NaN          NaN          NaN
# Tom Gu (pages 16-22)                NaN          NaN          NaN
# Sungmin Lee (pages 23-29)           NaN          NaN          NaN
# (25~Infinite)                       NaN          NaN          NaN
# Joab (pages 30-36)                  NaN          NaN          NaN
# Camille (pages 37-43)               NaN          NaN          NaN
# Edi (pages 44-50)                   NaN          NaN          NaN
# Matthew (pages 51-57)               NaN          NaN          NaN
# Ben (pages 58-64)                   NaN          NaN          NaN
# Kyro (pages 65-71)                  NaN          NaN          NaN
#
#                             Unnamed: 14  Unnamed: 15  Unnamed: 16
# Nikita (page 1)                     NaN          NaN          NaN
# Zane Zukovsky(pages 2-8)            NaN          NaN          NaN
# Kane A. Boyer (pages 9-15)          NaN          NaN          NaN
# Tom Gu (pages 16-22)                NaN          NaN          NaN
# Sungmin Lee (pages 23-29)           NaN          NaN          NaN
# (25~Infinite)                       NaN          NaN          NaN
# Joab (pages 30-36)                  NaN          NaN          NaN
# Camille (pages 37-43)               NaN          NaN          NaN
# Edi (pages 44-50)                   NaN          NaN          NaN
# Matthew (pages 51-57)               NaN          NaN          NaN
# Ben (pages 58-64)                   NaN          NaN          NaN
# Kyro (pages 65-71)                  NaN          NaN          NaN

# %%
df_descriptions = df['Title']
df_descriptions.count()
# Out:
# 389

# %%
res = []
for d in df_descriptions.values:
    if (not pd.isnull(d)):
        d = d.replace('\n','')
        d = d.strip()
        res.append(d)
res.pop(0)
print(res)
# descriptions = []
# for i in range(df_descriptions.count()):
#     d = df_descriptions[df_descriptions.index[i]]
#     if (not pd.isnull(d)):
#         d = d.replace('\n','')
#         d = d.strip()
#         descriptions.append(d)
# print(descriptions)
# Out:
# ['Portrait of Anne, Countess of Chesterfield', "Allegory of Charles IX as Mars and Allegory of Catherine de 'Medici as Juno", 'Cameo of Lucretia', 'Charity', 'Fragment from the Martyrdom of the Ten Thousand', 'Saint Bernard', 'An Angel', 'Madonna and Child', 'Hat Badge Representing Prudence', 'The Return from War: Mars Disarmed by Venus', 'St. John the Baptist', 'After', 'Before', 'Dish with Saint Peter', 'Madonna and Child with Two Donors', 'The Annunciation', 'Prince Charles Louis of the Palatinate with his Tutor Wolrad von Plessen in Historical Dress', 'Elijah Receiving Bread from the Widow of Zarephath', 'Venus and Adonis', 'Portrait of John, Lord Mountstuart, later 4th Earl and 1st Marquess of Bute', 'Portrait of a Man', 'Madonna of Humility', 'Sir James Gray, 2nd Bt.', 'Heads of Two Dominican Friars', 'The Abduction of Proserpine', 'Double Portrait', 'Pietà', 'Bacchante with an Ape', 'La Promenade', 'Portrait of Gabriel Bernard de Rieux', 'Saint Ginés de la Jara', 'Portrait of a Man with a Sheet of Music', 'John Whetham of Kirklington', 'Portrait of Francisco de los Cobos y Molina', 'The Abduction of Helen by Paris', 'Saint Gines de la Jara', 'Three Lovers', 'The Shade of Samuel Invoked by Saul', 'Book of Hours', 'Moses Striking Water from the Rock', 'Noli Me Tangere', 'Family Group in an Interior', 'The Annunciation', 'Antoine Singlin', 'Bust of a Man', 'Hope Nourishes Love', 'Infant', 'Bust of Alexis-Jean-Eustache Taitbout (1705 - 1778)', 'Portrait of William Burton Conyngham', 'Portrait of George de Ligne Gregory (1740 - 1822)', 'Thomas Howard, 2nd Earl of Arundel', 'Ahimelech Giving the Sword of Goliath to David', 'Lady Playing a Lute', 'The Calydonian Boar Hunt', 'Meeting of King Ferdinand of Hungary and the Cardinal-Infante Ferdinand of Spain at Nördlingen', 'Glaucus and Scylla', 'Diana and Her Nymphs Bathing', 'Christ Child', 'The Alchemist', 'The Mass of Saint Gregory the Great', 'Portrait of Marc de Villiers', 'The Vision of Saint Francis of Paola', 'Virgin and Child with Saint John the Baptist', 'The Convalescent', 'Saint Catherine of Siena Receiving the Stigmata', 'The Miraculous Communion of Saint Catherine of Siena', 'Portrait of Madame Bonnier de la Mosson as Diana (Constance-Gabrielle-Magdeleine du Monciel de Lauraille)', 'Portrait of Isabella of Portugal', 'Saint Sebastian Thrown into the Cloaca Maxima', 'The Crucifixion', 'The Holy Family', 'Bust of Maria Cerri Capranica', "Portrait bust of Monseigneur le duc d'Orléans", 'The Miraculous Communion of Saint Catherine of Siena', 'Landscape with Allegories of the Four Elements', 'Moroccan Horseman Crossing a Ford', 'Portrait of Madame Bonnier de la Mosson as Diana', 'Portrait of Isabella of Portugal', 'Saint Sebastian Thrown into the Cloaca Maxima', 'The Crucifixion', 'The Holy Family', 'Bust of Maria Cerri Capranica', 'Portrait of a Man', 'The Birth of Bacchus', 'Tray', 'The Stigmatization of Saint Francis, and Angel Crowning Saints Cecilia and Valerian', 'The Virgin Mary with Saints Thomas Aquinas and Paul', "Portrait bust of Monseigneur le duc d'Orléans", "La Vision de l'âme de Guy de Thurno", 'Les Visions du chevalier Tondal', "Tapestry: La Collation, from L'Histoire de l'empereur de la Chine Series", "Tapestry: Le Retour de la chasse, from L'Histoire de l'empereur de la Chine Series", 'Wall Bracket', 'Tapestry: Le Cheval rayé from Les Anciennes Indes Series', 'Pair of Firedogs', "Tapestry: L'Embarquement de l'impératrice, from L'Histoire de l'empereur de la Chine Series", 'Madonna and Child with the Infant Saint John the Baptist', 'Virgin Mourning the Dead Christ', 'The Death of Samson', 'Dancing Faun', 'The Sacrifice of Isaac', 'Portrait of a Man', 'Plaque depicting Jacob choosing Rachel to be his Bride', 'Saint Philip', 'Alexander the Great and Campaspe in the Studio of Apelles', 'Coronation of the Virgin', 'The Vicomtesse de Vaudreuil', 'The Annunciation', 'The Chiarito Tabernacle', 'The Race of the Riderless Horses', 'The Apostle Simon', 'Saint Seba ...

# %%
with open('getty_dataset/getty-titles.utf8.txt','w') as filehandle:
    for d in res:
        filehandle.write('%s\r'%d)
print("wrote file..")
# Out:
# wrote file..

# %%
text_file = open("getty_dataset/getty-titles.utf8.txt", "r")
titles = text_file.read().split('\n')
titles
# Out:
# ['Portrait of Anne, Countess of Chesterfield',
#  "Allegory of Charles IX as Mars and Allegory of Catherine de 'Medici as Juno",
#  'Cameo of Lucretia',
#  'Charity',
#  'Fragment from the Martyrdom of the Ten Thousand',
#  'Saint Bernard',
#  'An Angel',
#  'Madonna and Child',
#  'Hat Badge Representing Prudence',
#  'The Return from War: Mars Disarmed by Venus',
#  'St. John the Baptist',
#  'After',
#  'Before',
#  'Dish with Saint Peter',
#  'Madonna and Child with Two Donors',
#  'The Annunciation',
#  'Prince Charles Louis of the Palatinate with his Tutor Wolrad von Plessen in Historical Dress',
#  'Elijah Receiving Bread from the Widow of Zarephath',
#  'Venus and Adonis',
#  'Portrait of John, Lord Mountstuart, later 4th Earl and 1st Marquess of Bute',
#  'Portrait of a Man',
#  'Madonna of Humility',
#  'Sir James Gray, 2nd Bt.',
#  'Heads of Two Dominican Friars',
#  'The Abduction of Proserpine',
#  'Double Portrait',
#  'Pietà',
#  'Bacchante with an Ape',
#  'La Promenade',
#  'Portrait of Gabriel Bernard de Rieux',
#  'Saint Ginés de la Jara',
#  'Portrait of a Man with a Sheet of Music',
#  'John Whetham of Kirklington',
#  'Portrait of Francisco de los Cobos y Molina',
#  'The Abduction of Helen by Paris',
#  'Saint Gines de la Jara',
#  'Three Lovers',
#  'The Shade of Samuel Invoked by Saul',
#  'Book of Hours',
#  'Moses Striking Water from the Rock',
#  'Noli Me Tangere',
#  'Family Group in an Interior',
#  'The Annunciation',
#  'Antoine Singlin',
#  'Bust of a Man',
#  'Hope Nourishes Love',
#  'Infant',
#  'Bust of Alexis-Jean-Eustache Taitbout (1705 - 1778)',
#  'Portrait of William Burton Conyngham',
#  'Portrait of George de Ligne Gregory (1740 - 1822)',
#  'Thomas Howard, 2nd Earl of Arundel',
#  'Ahimelech Giving the Sword of Goliath to David',
#  'Lady Playing a Lute',
#  'The Calydonian Boar Hunt',
#  'Meeting of King Ferdinand of Hungary and the Cardinal-Infante Ferdinand of Spain at Nördlingen',
#  'Glaucus and Scylla',
#  'Diana and Her Nymphs Bathing',
#  'Christ Child',
#  'The Alchemist',
#  'The Mass of Saint Gregory the Great',
#  'Portrait of Marc de Villiers',
#  'The Vision of Saint Francis of Paola',
#  'Virgin and Child with Saint John the Baptist',
#  'The Convalescent',
#  'Saint Catherine of Siena Receiving the Stigmata',
#  'The Miraculous Communion of Saint Catherine of Siena',
#  'Portrait of Madame Bonnier de la Mosson as Diana (Constance-Gabrielle-Magdeleine du Monciel de Lauraille)',
#  'Portrait of Isabella of Portugal',
#  'Saint Sebastian Thrown into the Cloaca Maxima',
#  'The Crucifixion',
#  'The Holy Family',
#  'Bust of Maria Cerri Capranica',
#  "Portrait bust of Monseigneur le duc d'Orléans",
#  'The Miraculous Communion of Saint Catherine of Siena',
#  'Landscape with Allegories of the Four Elements',
#  'Moroccan Horseman Crossing a Ford',
#  'Portrait of Madame Bonnier de la Mosson as Diana',
#  'Portrait of Isabella of Portugal',
#  'Saint Sebastian Thrown into the Cloaca Maxima',
#  'The Crucifixion',
#  'The Holy Family',
#  'Bust of Maria Cerri Capranica',
#  'Portrait of a Man',
#  'The Birth of Bacchus',
#  'Tray',
#  'The Stigmatization of Saint Francis, and Angel Crowning Saints Cecilia and Valerian',
#  'The Virgin Mary with Saints Thomas Aquinas and Paul',
#  "Portrait bust of Monseigneur le duc d'Orléans",
#  "La Vision de l'âme de Guy de Thurno",
#  'Les Visions du chevalier Tondal',
#  "Tapestry: La Collation, from L'Histoire de l'empereur de la Chine Series",
#  "Tapestry: Le Retour de la chasse, from L'Histoire de l'empereur de la Chine Series",
#  'Wall Bracket',
#  'Tapestry: Le Cheval rayé from Les Anciennes Indes Series',
#  'Pair of Firedogs',
#  "Tapestry: L'Embarquement de l'impératrice, from L'Histoire de l'empereur de la Chine Series",
#  'Madonna and Child with the Infant Saint John the Baptist',
#  'Virgin Mourning the Dead Christ',
#  'The Death of Samson',
#  'Dancing Faun',
#  'The Sacrifice of Isaac',
#  'Portrait of a Man',
#  'Plaque depicting Jacob choosing Rachel to be his Bride',
#  'Saint Philip',
#  'Alexander the Great and Campaspe in the Studio of Apelles',
#  'Coronation of the Virgin',
#  'The Vicomtesse de Vaudreuil',
#  'The Annunciation',
#  'The Chiarito Tabernacle',
#  'The Race of the Riderless Horses',
#  'The Apostle Simon',
#  'Saint Sebastian Tended by an Angel',
#  'The Age of Augustus, the Birth of Christ',
#  'Saturn Devouring One of His Children',
#  'Mercury',
#  'Offering to Priapus',
#  'Herm of a Vestal Virgin',
#  'Pastoral Scene',
#  'Belvedere Antinous',
#  'Entrance to the Jardin Turc',
#  'Classical Landscape with Figures and Sculpture',
#  'Christ on the Mount of Olives',
#  'Rest on the Flight into Egypt',
#  'Saint Margaret',
#  'Belisarius',
#  'The Painter in His Studio',
#  'Bust of a Young Boy',
#  'Saint Jerome in the Wilderness',
#  'Lot and His Daughters',
#  'Spring in the Alps',
#  'Clorinda Rescuing Sofronia and Olindo',
#  'Samson with the Jawbone',
#  'Interior with Soldiers and Women',
#  'Marine Gods Paying Homage to Love',
#  'Charles de Saint-Albin, Archbishop of Cambrai',
#  "The Doctor's Visit",
#  'Neptune',
#  'Male Nude',
#  'Medal of Emperor Rudolf II',
#  'Hunt Goblet',
#  "Pair of decorative bronzes with the figures of L'Etude and La Philosophie",
#  'Head of a Young Man',
#  'The Archangel Michael Vanquishing the Devil',
#  'Housing the Stranger',
#  'Self-Portrait',
#  'Euclid',
#  'The Prophet Habakkuk and the Angel',
#  'Landscape with Mercury and Argus',
#  'Danaë and the Shower of Gold',
#  'Saint George',
#  'Saint John the Baptist',
#  'Dejanira (Autumn)',
#  'The Penitent Magdalene',
#  'Saints Lawrence and Stephen',
#  'Madonna and Child',
#  'Head of a Man',
#  'Bust of Pope Paul V',
#  'The Italian Comedians',
#  'Madonna and Child',
#  'Nativity',
#  'Bust of an African Woman',
#  'Bust of Jacob van Reygersberg',
#  'Self-Portrait, Yawning',
#  'Arii Matamoe',
#  'Saint Andrew',
#  'Wine Bottle Cooler',
#  'An Allegory of Passion',
#  "Albert Cahen d'Anvers",
#  'The Vision of Saint Bruno',
#  'Venus and Adonis',
#  'Portrait of Agostino Pallavicini',
#  'Bacchus and Ariadne',
#  'Saint Luke',
#  'A Premonstratensian Canon',
#  'Christ in Majesty',
#  'Warrior on Horseback',
#  'Mercury and Argus and Perseus and Medusa',
#  'Bust of Louis XV',
#  'Boy with a Dragon',
#  'Arrival of Saint Ursula at Cologne',
#  'The Annunciation',
#  'Saint John Baptizing in the River Jordan',
#  'Lucretia',
#  'The Supper at Emmaus',
#  'Pair of Busts: Louis XV and Marie Leczinska',
#  'Venus and Mars',
#  'Christ on the Cross',
#  'Shepherd with a Flute',
#  "The Doctor's Visit",
#  'Danaë and the Shower of Gold',
#  'The Eternal Feminine',
#  'Portrait of James Christie',
#  'Reclining Youth',
#  'Christ and the Samaritan Woman',
#  'Christ on the Cross with Saints Mary, John the Evangelist, and Catherine of Siena',
#  'Landscape with a Nymph and a Satyr',
#  'The Idolatry of Solomon',
#  'Dido and Aeneas',
#  'Madonna and Child with Two Hermit Saints',
#  'Christ Cleansing the Temple',
#  'Pan and Syrinx',
#  'Saint Francis and a Bishop Saint, Saint John the Baptist and Saint Dominic',
#  "Joseph and Potiphar's Wife",
#  'Portrait of the Sculptor Roland',
#  'Rembrandt Laughing',
#  'Saint Mary Magdalene at the Sepulchre',
#  'Angel',
#  'The Arrest of Christ',
#  'La Surprise',
#  'Charles-François Pinceloup de la Grange',
#  'Study for Saint Peter',
#  'Shepherd with his Dog',
#  'Lustered Plate with a Female Bust',
#  'Dance before a Fountain',
#  'Cup and Saucer',
#  'Plate with a Winged Putto on a Hobbyhorse',
#  'Figure of Venus Marina',
#  'Molded Dish with an Allegory of Love',
#  'Hunting Scene',
#  'Neptune with Dolphin',
#  'Venus at the Forge of Vulcan',
#  'Triumph of the Marine Venus',
#  'Bust of Simon of Trent',
#  'Allegorical Group with a Bust of an Architect',
#  'Belisarius',
#  'Musical Group on a Balcony',
#  'Allegory of Fortune',
#  'The Sacrifice of Polyxena',
#  'The Deposition',
#  'Arcadian Shepherds',
#  'Portrait of John Talbot, later 1st Earl Talbot',
#  'Achilles among the Daughters of Lycomedes',
#  'Mucius Scaevola Thrusting His Right Hand into the Flames before Lars Porsenna',
#  'Aurora Taking Leave of Tithonus',
#  'The Way to Calvary',
#  'Hercules and Omphale',
#  'Head of a Woman',
#  'David with His Sword',
#  'Portrait of a Bearded Man',
#  'Portrait of a Woman',
#  'Shepherd and Sleeping Shepherdess',
#  'Portrait of Barbara Kressin',
#  'Ideal Female Heads',
#  'Bathsheba After the Bath',
#  'The Drawing Lesson',
#  'Young Italian Woman at a Table',
#  'John, Fourteenth Lord Willoughby de Broke, and His Family',
#  'Saint John the Evangelist',
#  'Vase',
#  'Street Scene',
#  'The Temptation of Saint Anthony',
#  'Christ in Glory with Saints Celsus, Julian, Marcionilla and Basilissa',
#  'A Thebaid: Monks and Hermits in a Landscape',
#  'The Head of a Young Boy Crowned with Laurel',
#  'Magdaleine Pinceloup de la Grange, née de Parseval',
#  'No Title',
#  'The Country Dance',
#  'Plate with Hero and Leander',
#  'Dish with Saint Clare',
#  'Saint Matthew Writing His Gospel',
#  'The Ransom',
#  'The Milliners',
#  'Madonna and Child with a Male Saint, Catherine of Alexandria and a Donor',
#  'Madonna and Child with an Angel',
#  'Death of Messalina',
#  'Portrait of a Young Woman',
#  "Busts of Two Sisters: Bust of Mme. Brigitte François Elisabeth de Lansire, née Garnier d'Isle; Bust of Mme. Adélaïde Julie Mirleau de Neuville, née Garnier d'Isle",
#  'Relief portrait of Louis XIV',
#  'Heraldic Panel with the Arms of the Eberler Family',
#  'The Crucifixion',
#  'Seraph',
#  'Grotto of Sarrazine near Nans-sous-Sainte-Anne',
#  'Femme Debout I',
#  "Angel of the Citadel - Horse and Rider - Town's Guardian Angel",
#  'The Fall of the Rebel Angels',
#  'The Trinity with the Virgin, Saints John the Evangelist, Stephen and Lawrence and a Donor',
#  'Adoration of the Shepherds',
#  'The Vexed Man',
#  'Bust of Marie-Sébastien-Charles-François Fontaine de Biré',
#  'The Virgin and Child',
#  'Card Players',
#  'The Angel Taking Leave of Tobit and His Family',
#  'Virgin and Child with Saint John the Baptist and Mary Magdalene',
#  'Mars and Venus, Allegory of Peace',
#  'Figure of a Street Vendor',
#  'A Maid Milking a Cow in a Barn',
#  'Portrait of a Young Man',
#  'Bust of Winter',
#  'The Virgin as the Woman of the Apocalypse',
#  'Astronomer by Candlelight',
#  'Diana and Her Nymphs in a Landscape',
#  'Bacchanale',
#  'Portrait of a Woman with a Book of Music',
#  'The Banquet of Ahasuerus',
#  'Saints John the Baptist and John the Evangelist',
#  'Mortar',
#  'The Laundress',
#  'Portrait of Maria Frederike van Reede-Athlone at Seven Years of Age',
#  'Before the Ball',
#  'Portrait of a Halberdier',
#  'Head of Christ',
#  'Self-Portrait as Giuseppe Garibaldi',
#  'Cabinet on Stand',
#  'Mercury',
#  'Venus and Adonis',
#  'Portrait of Camillo Rospigliosi',
#  'Bust of Winter',
#  'Card Players',
#  'The Angel Taking Leave of Tobit and His Family',
#  'Madonna and Child in a Window',
#  'Virgin and Child with Saint John the Baptist and Mary Magdalene',
#  'The Laundress',
#  'Self-Portrait as Giuseppe Garibaldi',
#  'Mars and Venus, Allegory of Peace',
#  'Figure of a Street Vendor',
#  'Saint John the Baptist and Saint Dominic',
#  "Bust of Mme. Brigitte François Elisabeth de Lansire, née Garnier d'Isle",
#  '1930, Transporting Produce, Outskirts of Phoenix, Arizona',
#  '1919, Portland, Colorado',
#  'Comedian (Dance 1)',
#  'Fine',
#  'Fine',
#  'Fine',
#  'Fine',
#  'Mary Constable',
#  'Miss Constable, also known as Family Likeness',
#  '[Crying baby]',
#  '[Young boy]',
#  '[Smiling girl]',
#  '[Beatrice Wallich smiling]',
#  'Rinaldo and the Mirror-Shield',
#  "Rinaldo's Conquest of the Enchanted Forest",
#  '1945, Aliso Village, Boyle Heights, California',
#  '1927, Going Back to Morelia',
#  'Self Portrait as my Grandfather George Gregory',
#  'Daughter of Art History, Theater B',
#  '[Helplessness]',
#  '[Disgust]',
#  '[Disdain]',
#  '[Jules Talrich]',
#  '[Jules Talrich]',
#  '[Sad boy]',
#  '[Detail from "Young Girl Standing with Hand to Mouth"]',
#  'Ideal Female Head',
#  'Allegory of Charles IX as Mars',
#  'Torse de Dina',
#  'Saint John',
#  'Henry Hoare, "The Magnificent", of Stourhead',
#  'Portrait of Laurent-Nicolas de Joubert',
#  '1910, Leaving Morelia, Michoacán Mexico',
#  'Saint Francis and a Bishop Saint',
#  'Putto Holding Shield to His Right',
#  'The Scripture Reader',
#  '[Contempt]',
#  '[Child holding crying baby]',
#  'Shrugging the Shoulders',
#  '[Indignation]',
#  '[Crying child]',
#  '[Augustus Fooley]',
#  '[Smiling man]',
#  'Ideal Female Head',
#  'Portrait of Marie-Louise Joubert, neé Poulletier de Perigny',
#  'The Virgin',
#  'Saint John the Evangelist',
#  'A Prophet or Elder',
#  'Detached leaf from the Gradual of the Carthusian Monastery Santo Spirito near Lucca',
#  'Detached leaf from the Gradual of the Carthusian Monastery Santo Spirito near Lucca',
#  'Marine Scene',
#  'Marine Scene',
#  'The Participles or Grammar for Little Boys: Caught',
#  'Daughter of Art History, Theater A',
#  'Fine',
#  'Fine',
#  'Fine',
#  'Expulsion',
#  "Allegory of Catherine de' Medici as Juno",
#  'Lunette: profile portrait of Louis XIV',
#  'Saint Fiacre',
#  'Running Man',
#  "Bust of Mme. Adélaïde Julie Mirleau de Neuville, née Garnier d'Isle",
#  'Fire Dog',
#  'Detached leaf from the Gradual of the Carthusian Monastery Santo Spirito near Lucca',
#  'Marriage of the Arnolfini',
#  '1950, San Diego, California',
#  'Fine',
#  'Untitled',
#  '[Young Girl with an Opened Book on Her Lap]',
#  'Nursey and Baby, Bus Bus, Baby and Nursey, Hush Hush!',
#  '']

# %%
from textgenrnn import textgenrnn
textgen = textgenrnn()
textgen.train_on_texts(titles, num_epochs=10)
textgen.save('getty-titles-model-e10.hdf5')
# Out:
# Training on 11,420 character sequences.
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# WARNING:tensorflow:From /anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:102: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# Epoch 1/10
# 89/89 [==============================] - 12s 130ms/step - loss: 2.0731
# ####################
# Temperature: 0.2
# ####################
# Saint Coronal of Saint Saint Marine de Slame and Christ
#
# Arina and Marie of the Saint Marine of Angel
#
# Angel of the Saint Saint Child with Saint Saint Saint Saint Saint Saint Saint Saint Saint Saint Girl of Saint Saint Saint Saint Child and Angel
#
# ####################
# Temperature: 0.5
# ####################
# Hards and Allegoriatrilist
#
# Family de women
#
# Saint His Saint Madion of Botht of Angel
#
# ####################
# Temperature: 1.0
# ####################
# [Scenemait]
#
# Bapley Winner L'Madonnecet, the Athie frog and Madan Saricationest
#
# The Anc Affrance role
#
# Epoch 2/10
# 89/89 [==============================] - 11s 122ms/step - loss: 1.4796
# ####################
# Temperature: 0.2
# ####################
# Portrait boy
#
# Saint Mars and Child with Saint Mars of Saint Marine Called
#
# The Saint Francical Saint John the Saint John the Marine and Saint John the Saint Saint John the Saint Marriage of Saint Marriage and Christ
#
# ####################
# Temperature: 0.5
# ####################
# Portrait behid
#
# Pleaner and Allegory of a Boy Gintoberd of a Man
#
# Portrait of Morual
#
# ####################
# Temperature: 1.0
# ####################
# Thing a Vision of Michanist
#
# Saint Spo van Psry den with Schendicans
#
# Aporon Reterco
#
# Epoch 3/10
# 89/89 [==============================] - 12s 133ms/step - loss: 1.2491
# ####################
# Temperature: 0.2
# ####################
# The Carthun of the Cardine of the Angel
#
# Portrait of a Man
#
# Saint John the Series
#
# ####################
# Temperature: 0.5
# ####################
# The Angel
#
# The Beander Saint John the Age
#
# The Annunciation
#
# ####################
# Temperature: 1.0
# ####################
# Estracialphile Condocist into the Mary Interior
#
# Boby at Winning Debicho
#
# What he debust
#
# Epoch 4/10
# 89/89 [==============================] - 11s 120ms/step - loss: 1.0911
# ####################
# Temperature: 0.2
# ####################
# The Angel of the Saint John the Self-Portrait
#
# The Angel of the Infant
#
# The Angel de John the Baptist
#
# ####################
# Temperature: 0.5
# ####################
# Manstority Christ in Saint John the Angel
#
# The Crucifixion
#
# [Young Girl Spircastian)
#
# ####################
# Temperature: 1.0
# ####################
# Calefition in the Banape
#
# Dent as Diana as Tailon
#
# Portrait of a Los Magnix, Going Laundress
#
# Epoch 5/10
# 89/89 [==============================] - 11s 118ms/step - loss: 0.9634
# ####################
# Temperature: 0.2
# ####################
# The Angel Taking Leave of Catherine of Saint John the Shower of Maria Conter
#
# The Catherine of Age
#
# The Angel Taking Saint John the Came of a Man
#
# ####################
# Temperature: 0.5
# ####################
# Herm of the Carthusian Monastery Saint John the Rise of Maria
#
# The Portrait of Laureut
#
# [Child with Saint Saint Ports and His Family Capranica
#
# ####################
# Temperature: 1.0
# ####################
# Arcus and Lawran de Ding
#
# La Nuclet,  Arre Rucio Saint, an Archazin Wall
#
# Battome de Pathion de 1917, from Catherine of Saint Madonge of Stander
#
# Epoch 6/10
# 89/89 [==============================] - 11s 124ms/step - loss: 0.8624
# ####################
# Temperature: 0.2
# ####################
# Saint John the Baptist
#
# The Angel Taking Leave of Marie - Mary Magdalene
#
# Saint John the Baptist
#
# ####################
# Temperature: 0.5
# ####################
# Lustered Pariting Adonis
#
# Head of a Young Man
#
# The Fordian The Annuncian Marine Grewndee de Bacchus
#
# ####################
# Temperature: 1.0
# ####################
# Erletted lard Mars de an African Annuncia͕ Comedus
#
# Portulicempishne of Saint John the Dranisus
#
# The Grabby from the Crossporn Franciat
#
# Epoch 7/10
# 89/89 [==============================] - 11s 125ms/step - loss: 0.7799
# ####################
# Temperature: 0.2
# ####################
# The Angel Taking Leave of the Shower of Allegory of Child with an Angel
#
# The Annunciation
#
# The Sathingt and Saint John the Baptist
#
# ####################
# Temperature: 0.5
# ####################
# The Virgin and Christ
#
# The Angel Taking Leave of the Angel
#
# Receivit
#
# ####################
# Temperature: 1.0
# ####################
# His RC of the Young
#
# Bathshies of Celanci
#
# [Indignation]
#
# Epoch 8/10
# 89/89 [==============================] - 11s 127ms/step - loss: 0.7115
# ####################
# Temperature: 0.2
# ####################
# The Annunciation
#
# The Annunciation
#
# The Annunciation
#
# ####################
# Temperature: 0.5
# ####################
# Interior with a Landscape
#
# The Evangelist
#
# The Annunciation
#
# ####################
# Temperature: 1.0
# ####################
# Carditian Cross Borty
#
# No choosing 1945, Saucer King Huth and Helen Lol Gregory progres with Anlefei
#
# Bust of Momding in Herando (Dance 10, Mandal Garbinivate the Windownidle Return anthac-Poypust and Annunciation
#
# Epoch 9/10
# 89/89 [==============================] - 11s 123ms/step - loss: 0.6547
# ####################
# Temperature: 0.2
# ####################
# The Annunciation
#
# The Angel Taking Leave of Shepherds
#
# The Angel Taking Leave of Tobit
#
# ####################
# Temperature: 0.5
# ####################
# Saint Dog
#
# Christ on the Crying Shower of Allegory of Child with Trainerius, Julian Card Players
#
# Madonna and Child with a Young Marine Santia and Her Nating Virgin
#
# ####################
# Temperature: 1.0
# ####################
# [Sad baby]
#
# Saint Lo Californant Tabqus Gredird
#
# A Couldino Gregory Bown Fraunt Turns-nona
#
# Epoch 10/10
# 89/89 [==============================] - 10s 116ms/step - loss: 0.6112
# ####################
# Temperature: 0.2
# ####################
# The Annunciation
#
# The Annunciation
#
# The Annunciation
#
# ####################
# Temperature: 0.5
# ####################
# The Mouss of Arrest
#
# Marine Scene
#
# Saint John the Baptist
#
# ####################
# Temperature: 1.0
# ####################
# Title Peace Gregoriet
#
# Receivit Card van Rebection
#
# Goach position

# %%
# comment out below to read a saved model:
textgen = textgenrnn('getty-titles-model-e10.hdf5')
gem_titles = []

for i in range(30):
    gen_titles+=textgen.generate(10, temperature=0.5, return_as_list=True)

for t in gen_titles:
    if t in titles:
        gen_titles.remove(t)
gen_titles = list(set(gen_titles))

print(gen_titles)
# Out:
# 100%|██████████| 10/10 [00:02<00:00,  3.43it/s]
# 100%|██████████| 10/10 [00:02<00:00,  2.75it/s]
# 100%|██████████| 10/10 [00:02<00:00,  3.52it/s]
# 100%|██████████| 10/10 [00:02<00:00,  2.80it/s]
# 100%|██████████| 10/10 [00:03<00:00,  1.94it/s]
# 100%|██████████| 10/10 [00:02<00:00,  2.92it/s]
# 100%|██████████| 10/10 [00:02<00:00,  4.49it/s]
# 100%|██████████| 10/10 [00:02<00:00,  2.67it/s]
# 100%|██████████| 10/10 [00:02<00:00,  4.52it/s]
# 100%|██████████| 10/10 [00:02<00:00,  3.02it/s]
# ['The Boy Gaby as John the Baptist', 'The Idolath and Laundress', 'Bust of an Aposta Rosa', 'Elijah Scene', 'Saint John the Baptist and Barbara', 'Madonna and Child with the Bust of a Woman', 'Bust of Saint Communion of Saint Magdalene', 'Fine', 'Neptune with the Archans-Anne', 'Saint Morticupe de la Chine Self-Portrait as Mary Magdalene', 'Mary Magdalene at the Devil', 'The Wilder on Stand', 'The Christ Moner', 'Bust of Maria Simps de Prophet', 'The Brandrik Receiving Storine', 'Allegory of Conquest of the Bearded Mary Monselis', 'Bust of a Young Gray, and a  Man', 'The Christ Monastery Saints John the Baptist and Saint John the Baptist', 'Portrait of Gabriel Series', 'The Angel Tonigus', 'Christ on the Allegory of Peace', 'Double Portrait of Louis XV de la Chine Marcionilla of Trusis, California', 'Diana and Her Nymphs in a Family', 'The Maripr Mosas Donor', 'The Andrester', 'The Francis of Paul', '[Dised at Saint Saint John Tall', 'Saint Peace', 'The Crucifixion', 'An Allegory of Peace', 'Bust of Monseigneur lends', 'Saint John the Baptist and Mary Magdalene', 'The Virgin as the Baptist', 'Shepherd with the Carthune de Landscape', 'Portrait of a Man', "Donald of Allegory of Catherine de 'Evangian Bacchus of Portrait", 'The Angel Taking Leave of Saints La Teromis-Nymphs and Alexandither of Allegory of Prophet Infant', 'The Christ Monastery Santo and the Shower of Fiarofoff', 'Saint Peace', 'Christ in Venus', 'The Calvary', 'The Samuel Theater Boy Tonise', 'The Carthusian Monastery Santo and Saint John the Baptist and Mary Magdalene', 'Madonna and Child with the Shower of Two Donors', 'Saint John the Baptist', 'The Virgin Mountle with an Alexander', 'Portrait of a Boy Group Mary with a Family', 'Portrait of a Boy', 'The Drawing Leave of Child with Saint John the Baptist', 'Mercury and Can wittone with a Winged Produce of the Shower of Woman', 'Portrait of a Man', 'Portrait of a Man', 'Portrait of a Man', 'Saint Gines', 'Madonna and Adonis', 'Marine Scene', 'The Catherine of Saint Mary Clean de Luccan', 'Portrait of a Man and Saint John the Baptist', 'The Virgin and Child with Saints Larres de Landscape with a Baptizing Siena', 'Bust of Marie-Lesting Cleanger', 'Portrait of a Man', 'Portrait of a Man', 'The Miraculous Man', 'Bust of Mars Thomas It', 'Bust of a Young Man', 'Saint Peace', 'Allegorical Group with a Bust of Saint Communion of  Barbara', 'The Annunciation', 'Portrait of Campare of Bacchus', 'Allegory of Peace', 'The Diana and Her Nymphs Restaurh', 'The Annunciation', 'Mars and Venus Card Marine Gregory of Carthusian Monastery Saint Jon', 'The Annunciation', 'The Annunciation', 'Arcadian Francis and a Bacchus, Lansiris Bust of Medica']

# %%
df_title = pd.DataFrame(gen_titles)
df_title.to_excel('title_data.xls')

display(df_title)
# Out:
#                                                     0
# 0                    The Boy Gaby as John the Baptist
# 1                           The Idolath and Laundress
# 2                              Bust of an Aposta Rosa
# 3                                        Elijah Scene
# 4                  Saint John the Baptist and Barbara
# 5          Madonna and Child with the Bust of a Woman
# 6          Bust of Saint Communion of Saint Magdalene
# 7                                                Fine
# 8                       Neptune with the Archans-Anne
# 9   Saint Morticupe de la Chine Self-Portrait as M...
# 10                        Mary Magdalene at the Devil
# 11                                The Wilder on Stand
# 12                                   The Christ Moner
# 13                     Bust of Maria Simps de Prophet
# 14                     The Brandrik Receiving Storine
# 15  Allegory of Conquest of the Bearded Mary Monselis
# 16                   Bust of a Young Gray, and a  Man
# 17  The Christ Monastery Saints John the Baptist a...
# 18                         Portrait of Gabriel Series
# 19                                  The Angel Tonigus
# 20                    Christ on the Allegory of Peace
# 21  Double Portrait of Louis XV de la Chine Marcio...
# 22                   Diana and Her Nymphs in a Family
# 23                             The Maripr Mosas Donor
# 24                                      The Andrester
# 25                                The Francis of Paul
# 26                    [Dised at Saint Saint John Tall
# 27                                        Saint Peace
# 28                                    The Crucifixion
# 29                               An Allegory of Peace
# ..                                                ...
# 46         Portrait of a Boy Group Mary with a Family
# 47                                  Portrait of a Boy
# 48  The Drawing Leave of Child with Saint John the...
# 49  Mercury and Can wittone with a Winged Produce ...
# 50                                  Portrait of a Man
# 51                                  Portrait of a Man
# 52                                  Portrait of a Man
# 53                                        Saint Gines
# 54                                 Madonna and Adonis
# 55                                       Marine Scene
# 56        The Catherine of Saint Mary Clean de Luccan
# 57       Portrait of a Man and Saint John the Baptist
# 58  The Virgin and Child with Saints Larres de Lan...
# 59                     Bust of Marie-Lesting Cleanger
# 60                                  Portrait of a Man
# 61                                  Portrait of a Man
# 62                                 The Miraculous Man
# 63                             Bust of Mars Thomas It
# 64                                Bust of a Young Man
# 65                                        Saint Peace
# 66  Allegorical Group with a Bust of Saint Communi...
# 67                                   The Annunciation
# 68                     Portrait of Campare of Bacchus
# 69                                  Allegory of Peace
# 70                  The Diana and Her Nymphs Restaurh
# 71                                   The Annunciation
# 72  Mars and Venus Card Marine Gregory of Carthusi...
# 73                                   The Annunciation
# 74                                   The Annunciation
# 75  Arcadian Francis and a Bacchus, Lansiris Bust ...
#
# [76 rows x 1 columns]
